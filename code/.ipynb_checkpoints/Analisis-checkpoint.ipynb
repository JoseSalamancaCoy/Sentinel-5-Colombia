# %%
from netCDF4 import Dataset
from os import scandir
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Polygon
import pandas as pd
import geoplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-258-e5ef0755c1be> in <module>
#       6 from shapely.geometry import Polygon
#       7 import pandas as pd
# ----> 8 import geoplot
#
# ~\Anaconda3\lib\site-packages\geoplot\__init__.py in <module>
# ----> 1 from .geoplot import (
#       2     pointplot, polyplot, choropleth, cartogram, kdeplot, sankey, voronoi, quadtree, webmap,
#       3     __version__
#       4 )
#       5 from .crs import (
#
# ~\Anaconda3\lib\site-packages\geoplot\geoplot.py in <module>
#      15 import pandas as pd
#      16 import descartes
# ---> 17 import contextily as ctx
#      18 import mapclassify as mc
#      19
#
# ~\Anaconda3\lib\site-packages\contextily\__init__.py in <module>
#       5 from . import tile_providers as sources
#       6 from ._providers import providers
# ----> 7 from .place import Place, plot_map
#       8 from .tile import *
#       9 from .plotting import add_basemap, add_attribution
#
# ~\Anaconda3\lib\site-packages\contextily\place.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 from warnings import warn
# ----> 6 from .tile import howmany, bounds2raster, bounds2img, _sm2ll, _calculate_zoom
#       7 from .plotting import INTERPOLATION, ZOOM, add_attribution
#       8 from . import providers
#
# ~\Anaconda3\lib\site-packages\contextily\tile.py in <module>
#      14
#      15 import numpy as np
# ---> 16 import rasterio as rio
#      17 from PIL import Image
#      18 from joblib import Memory as _Memory
#
# ~\Anaconda3\lib\site-packages\rasterio\__init__.py in <module>
#      20             pass
#      21
# ---> 22 from rasterio._base import gdal_version
#      23 from rasterio.drivers import is_blacklisted
#      24 from rasterio.dtypes import (
#
# ImportError: DLL load failed: No se encontró el proceso especificado.

# %%
def ls_(path): 
    return [obj.name for obj in scandir(path) if obj.is_file()]

files=ls_("C:/Users/IN2Sense/Documents/RACIMO/RACIMOAIRE/Datos_satelites_202001_202003")
files = [i for i in files if(i[::-1][:4] == "fdcn")]

# %%
rootgrp = Dataset(files[3], "r", format="NETCDF4")

# %%
Time = {}
Time["start"] = rootgrp.time_coverage_start
Time["end"] = rootgrp.time_coverage_end
Time["create"] = rootgrp.date_created

geospatial = {}
geospatial["lat_min"] = rootgrp.geospatial_lat_min
geospatial["lat_max"] = rootgrp.geospatial_lat_max
geospatial["lon_min"] = rootgrp.geospatial_lon_min
geospatial["lon_max"] = rootgrp.geospatial_lon_max

AERO_340_380_precision = rootgrp.groups['PRODUCT'].variables['aerosol_index_340_380_precision'][:].data[0]
AERO_340_380 = rootgrp.groups['PRODUCT'].variables['aerosol_index_340_380'][:].data[0]
AERO_354_388_precision = rootgrp.groups['PRODUCT'].variables['aerosol_index_354_388_precision'][:].data[0]
AERO_354_388 = rootgrp.groups['PRODUCT'].variables['aerosol_index_354_388'][:].data[0]

latitude  = rootgrp.groups['PRODUCT'].variables['latitude'][:].data[0]
longitude = rootgrp.groups['PRODUCT'].variables['longitude'][:].data[0]

# %%
fig = plt.figure(figsize=(10, 8))

ax = fig.add_subplot(111)
ax.set_title('colorMap')
plt.imshow(AERO_340_380)
ax.set_aspect('equal')


plt.colorbar(orientation='vertical')
plt.show()

# %%
rootgrp
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.7
#     institution: KNMI
#     source: Sentinel 5 precursor, TROPOMI, space-borne remote sensing, L2
#     history: 2020-02-13 19:20:27 f_s5pops tropnll2dp /mnt/data1/storage_nrt/cache_nrt/WORKING-617411128/JobOrder.617410749.xml
#     summary: TROPOMI/S5P Aerosol Index 1-Orbit L2 Swath 7x3.5km
#     tracking_id: 4584da37-6e06-4744-9ed8-fcd5f0e6aaf0
#     id: S5P_NRTI_L2__AER_AI_20200213T183253_20200213T183753_12107_01_010302_20200213T191550
#     time_reference: 2020-02-13T00:00:00Z
#     time_reference_days_since_1950: 25610
#     time_reference_julian_day: 2458892.5
#     time_reference_seconds_since_1970: 1581552000
#     time_coverage_start: 2020-02-13T18:32:47Z
#     time_coverage_end: 2020-02-13T18:37:59Z
#     time_coverage_duration: PT312.473S
#     time_coverage_resolution: PT0.840S
#     orbit: 12107
#     references: http://www.tropomi.eu/data-products/aerosol-index
#     processor_version: 1.3.2
#     keywords_vocabulary: AGU index terms, http://publications.agu.org/author-resource-center/index-terms/
#     keywords: 0300 Atmospheric Composition and Structure; 0305 Aerosols and Particles; 0360 Radiation, Transmission and Scattering; 3311 Clouds and Aerosols; 3360 Remote Sensing
#     standard_name_vocabulary: NetCDF Climate and Forecast Metadata Conventions Standard Name Table (v29, 08 July 2015), http://cfconventions.org/standard-names.html
#     naming_authority: nl.knmi
#     cdm_data_type: Swath
#     date_created: 2020-02-13T19:20:00Z
#     creator_name: The Sentinel 5 Precursor TROPOMI Level 2 products are developed with funding from the European Space Agency (ESA), the Netherlands Space Office (NSO), the Belgian Science Policy Office, the German Aerospace Center (DLR) and the Bayerisches Staatsministerium für Wirtschaft und Medien, Energie und Technologie (StMWi).
#     creator_url: http://www.tropomi.eu
#     creator_email: EOSupport@Copernicus.esa.int
#     project: Sentinel 5 precursor/TROPOMI
#     geospatial_lat_min: -22.887667
#     geospatial_lat_max: 0.5257167
#     geospatial_lon_min: -60.073185
#     geospatial_lon_max: -88.64321
#     license: No conditions apply
#     platform: S5P
#     sensor: TROPOMI
#     spatial_resolution: 7x3.5km2
#     cpp_compiler_version: g++ (GCC) 4.8.5 20150623 (Red Hat 4.8.5-11)
#     cpp_compiler_flags: -g -O2 -fPIC -std=c++11 -W -Wall -Wno-ignored-qualifiers -Wno-write-strings -Wno-unused-variable -DTROPNLL2DP
#     f90_compiler_version: GNU Fortran (GCC) 4.8.5 20150623 (Red Hat 4.8.5-11)
#     f90_compiler_flags: -gdwarf-3 -O2 -fPIC -cpp -ffpe-trap=invalid -fno-range-check -frecursive -fimplicit-none -ffree-line-length-none -DTROPNLL2DP -Wuninitialized -Wtabs
#     build_date: 2019-04-05T12:04:00Z
#     revision_control_identifier:
#     geolocation_grid_from_band: 3
#     identifier_product_doi: N/A
#     identifier_product_doi_authority: http://dx.doi.org/
#     algorithm_version: 1.2.0
#     title: TROPOMI/S5P Aerosol Index 1-Orbit L2 Swath 7x3.5km
#     product_version: 1.1.0
#     processing_status: Nominal
#     Status_MET_2D: Nominal
#     dimensions(sizes):
#     variables(dimensions):
#     groups: PRODUCT, METADATA

# %%
rootgrp.Status_MET_2D
# Out:
# 'Nominal'

# %%
len(data[0][0])
# Out:
# 450

# %%
rootgrp.groups['PRODUCT'].groups['SUPPORT_DATA'].groups['INPUT_DATA']
# Out:
# <class 'netCDF4._netCDF4.Group'>
# group /PRODUCT/SUPPORT_DATA/INPUT_DATA:
#     dimensions(sizes):
#     variables(dimensions): float32 surface_altitude(time,scanline,ground_pixel), float32 surface_altitude_precision(time,scanline,ground_pixel), uint8 surface_classification(time,scanline,ground_pixel), int32 instrument_configuration_identifier(time,scanline), int16 instrument_configuration_version(time,scanline), float32 scaled_small_pixel_variance(time,scanline,ground_pixel), float32 eastward_wind(time,scanline,ground_pixel), float32 northward_wind(time,scanline,ground_pixel), float32 ozone_total_column(time,scanline,ground_pixel), float32 surface_pressure(time,scanline,ground_pixel)
#     groups:

# %%
map_data = gpd.read_file("maps/colombia_area.geojson")
map_data.head()
# Out:
#      id                                           geometry
# 0  None  MULTIPOLYGON (((-77.08040 10.15939, -73.92012 ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
 
# Control del título y los ejes
ax.set_title('Natalidad por Provincias en España, 2018', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
 
# Mostrar el mapa finalizado
map_data.plot( cmap='plasma', ax=ax, zorder=5)

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(column='pop_est', ax=ax, legend=True)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
world.plot(column='pop_est', ax=ax, legend=True, cax=cax)

# %%
map_data["geometry"].data
# Out:
# C:\Users\IN2Sense\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: GeoSeries.data is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# array([<shapely.geometry.multipolygon.MultiPolygon object at 0x000001C8CF9C22E8>],
#       dtype=object)

# %%
south_america = world[world["continent"] == "South America"]
polygon = Polygon([(-80, -10), (-80, 20), (-60, 20), (-60, -10)])
poly_gdf = gpd.GeoDataFrame([1], geometry=[polygon], crs=world.crs)

# %%
fig, (ax1) = plt.subplots(figsize=(15, 12))
world.plot(ax=ax1)
poly_gdf.boundary.plot(ax=ax1, color="red")
ax1.set_title("All Unclipped World Data", fontsize=20)
#ax1.set_axis_off()
plt.show()

# %%
poly_gdf
# Out:
#    0                                           geometry
# 0  1  POLYGON ((-80.00000 -10.00000, -80.00000 20.00...

# %%
world_clipped = gpd.clip(world, polygon)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-215-0da60581a48f> in <module>
# ----> 1 world_clipped = gpd.clip(world, polygon)
#
# AttributeError: module 'geopandas' has no attribute 'clip'

# %%
s = geopandas.GeoSeries([Point(1, 1), Point(2, 2), Point(3, 3)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-218-590ba8e993ec> in <module>
# ----> 1 s = geopandas.GeoSeries([Point(1, 1), Point(2, 2), Point(3, 3)])
#
# NameError: name 'geopandas' is not defined

# %%
df = pd.DataFrame(
    {
     'Latitude': latitude[0],
     'Longitude': longitude[0]
    })

# %%
import geopandas
import geoplot

world = geopandas.read_file(
    geopandas.datasets.get_path('naturalearth_lowres')
)
boroughs = geopandas.read_file(
    geoplot.datasets.get_path('nyc_boroughs')
)
collisions = geopandas.read_file(
    geoplot.datasets.get_path('nyc_injurious_collisions')
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-238-d8af561bf88a> in <module>
#       1 import geopandas
# ----> 2 import geoplot
#       3
#       4 world = geopandas.read_file(
#       5     geopandas.datasets.get_path('naturalearth_lowres')
#
# ModuleNotFoundError: No module named 'geoplot'

# %%
len(AERO_340_380_precision)
# Out:
# 373
